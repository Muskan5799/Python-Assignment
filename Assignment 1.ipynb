# %%
'''Question 1:
Write a Python program to print your name and favourite colour on two
separate lines.'''
# Out:
# 'Question 1:\nWrite a Python program to print your name and favourite colour on two\nseparate lines.'

# %%
print("My Name: Muskan Chinchkhede")
print("My Favourite Colour : Blue")
# Out:
# My Name: Muskan Chinchkhede
# My Favourite Colour : Blue

# %% [markdown]
# Question 2:
# Write a Python program that prints the result of adding 7 and 8.

# %%
result = 7 + 8
print("7+8 =", result)
# Out:
# 7+8 = 15

# %% [markdown]
# Question 3:
# Use the print function to display the following text exactly as it is:
# Python is fun!
# Let's learn together.

# %%
print("Python is fun!")
print("Let's learn together.")
# Out:
# Python is fun!
# Let's learn together.

# %% [markdown]
# Quetion 4: Python program to calculate and print the result of multiplying 6 by 9

# %%
result = 6 * 9
print(result)
# Out:
# 54

# %% [markdown]
# Question 5:
# Write a Python program that prints the result of adding 5 + 5 and
# multiplying 2 * 3 in a single line of code.

# %%
print(5 + 5, 2 * 3)
# Out:
# 10 6

# %% [markdown]
# 1. Take the name A as input from the user and print "Hello A", where A is
# the name in input.

# %%
A = input("Enter your name: ")
print("Hello", A)
# Out:
# Enter your name: Muskan
# Hello Muskan

# %% [markdown]
# 2. You have x rupees in your savings. You google pay y rupees, print your
# bank balance

# %%
x = float(input("savings amount (in rupees): "))
y = float(input(" paid  Google Pay (in rupees): "))

balance = x - y

print("balance is:", balance, "rupees")
# Out:
# savings amount (in rupees): 5000
#  paid  Google Pay (in rupees): 1500
# balance is: 3500.0 rupees

# %% [markdown]
# 3. Print the first five letters of the English alphabet i.e. A, B, C, D and E.
# one below each other

# %%
print("A")
print("B")
print("C")
print("D")
print("E")
# Out:
# A
# B
# C
# D
# E

# %% [markdown]
# 4. Take two names A and B as input from the user, and print "A says Hi to
# B" (Without quotations), where A and B are the names in input.

# %%
A = input("Enter name : ")
B = input("Enter name : ")

print(A, "says Hi to", B)
# Out:
# Enter name : A
# Enter name : B
# A says Hi to B
